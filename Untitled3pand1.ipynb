# %% [markdown]
# <a href="https://colab.research.google.com/github/ValeriaTri01/IA/blob/main/Untitled3pand1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# PANDAS HAS TWO DATA STRUCTER
#SERIES
import pandas as pd
tmp=pd.Series(data=(100,200,300,400),index=['carlos','juan','cristhian','maria'])

# %%
print(tmp)
tmp.shape
# Out:
# carlos       100
# juan         200
# cristhian    300
# maria        400
# dtype: int64
# (4,)

# %%
print(tmp[-2])
# Out:
# 300

# %%
tmp*2
# Out:
# carlos       200
# juan         400
# cristhian    600
# maria        800
# dtype: int64

# %%
print(tmp[[1,2,3]])
# Out:
# juan         200
# cristhian    300
# maria        400
# dtype: int64

# %% [markdown]
# index

# %%
tmp.index
# Out:
# Index(['carlos', 'juan', 'cristhian', 'maria'], dtype='object')

# %% [markdown]
# dicionrio

# %%
# creating a dictionary
my_dict = {'name':'john', 'age': 25, 'city':'new yprk'}
print(my_dict)
# Out:
# {'name': 'john', 'age': 25, 'city': 'new yprk'}

# %%
#estructura de datos
aux={'one':pd.Series([1,2,3],index=['aplle','ball','clock']),
'two':pd.Series([10,20,30],index=['pineaplle','watemelon', 'banana'])}

# %%
df=pd.DataFrame(aux)

# %%
df.shape
# Out:
# (6, 2)

# %%
df
# Out:
#            one   two
# aplle      1.0   NaN
# ball       2.0   NaN
# banana     NaN  30.0
# clock      3.0   NaN
# pineaplle  NaN  10.0
# watemelon  NaN  20.0

# %%
df.index
# Out:
# Index(['aplle', 'ball', 'banana', 'clock', 'pineaplle', 'watemelon'], dtype='object')

# %%
df.columns
# Out:
# Index(['one', 'two'], dtype='object')

# %%
df['three']=df['one']*df['two']

# %%
df
# Out:
#            one   two  three
# aplle      1.0   NaN    NaN
# ball       2.0   NaN    NaN
# banana     NaN  30.0    NaN
# clock      3.0   NaN    NaN
# pineaplle  NaN  10.0    NaN
# watemelon  NaN  20.0    NaN

# %%
df['three']=df['one']+df['two']
df
# Out:
#            one   two  filtro  three
# aplle      1.0   NaN   False    NaN
# ball       2.0   NaN   False    NaN
# banana     NaN  30.0   False    NaN
# clock      3.0   NaN    True    NaN
# pineaplle  NaN  10.0   False    NaN
# watemelon  NaN  20.0   False    NaN

# %% [markdown]
# imprimir valores

# %%
df['filtro']=df['one']>2
df
# Out:
#            one   two  filtro  three
# aplle      1.0   NaN   False    NaN
# ball       2.0   NaN   False    NaN
# banana     NaN  30.0   False    NaN
# clock      3.0   NaN    True    NaN
# pineaplle  NaN  10.0   False    NaN
# watemelon  NaN  20.0   False    NaN

# %% [markdown]
# eliminar columnas

# %%
del df['three']

# %% [markdown]
# case stop

# %%
tags=pd.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/tags.csv')
ratings=pd.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/ratings01.csv')
movies = pd.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/movies.csv')

# %%
tags.shape
# Out:
# (465564, 4)

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
tags[:10]
# Out:
#    userId  movieId               tag   timestamp
# 0      18     4141       Mark Waters  1240597180
# 1      65      208         dark hero  1368150078
# 2      65      353         dark hero  1368150079
# 3      65      521     noir thriller  1368149983
# 4      65      592         dark hero  1368150078
# 5      65      668         bollywood  1368149876
# 6      65      898  screwball comedy  1368150160
# 7      65     1248     noir thriller  1368149983
# 8      65     1391              mars  1368150055
# 9      65     1617          neo-noir  1368150217

# %%
print (tags['tag'][:10])
# Out:
# 0         Mark Waters
# 1           dark hero
# 2           dark hero
# 3       noir thriller
# 4           dark hero
# 5           bollywood
# 6    screwball comedy
# 7       noir thriller
# 8                mars
# 9            neo-noir
# Name: tag, dtype: object

# %%
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# 8                                       Action
# 9                    Action|Adventure|Thriller

# %%
ratings.head(10)
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580
# 5       1      112     3.5  1094785740
# 6       1      151     4.0  1094785734
# 7       1      223     4.0  1112485573
# 8       1      253     4.0  1112484940
# 9       1      260     4.0  1112484826

# %%
ratings.tail(10)
# Out:
#          userId  movieId  rating   timestamp
# 1999990   13567    54004     3.5  1262994633
# 1999991   13567    58154     4.0  1262994642
# 1999992   13567    58559     5.0  1262994213
# 1999993   13567    59333     3.5  1262994526
# 1999994   13567    59369     4.0  1262764264
# 1999995   13567    59725     3.5  1262994714
# 1999996   13567    63062     5.0  1262764337
# 1999997   13567    64957     5.0  1262764172
# 1999998   13567    65216     4.5  1262994367
# 1999999   13567    66203     4.0  1262994418

# %%
tags.tail(10)
# Out:
#         userId  movieId                               tag   timestamp
# 465554  138446     3489                visually appealing  1358983822
# 465555  138446     7045                   family friendly  1358983660
# 465556  138446     7045  Scary Movies To See on Halloween  1358983660
# 465557  138446     7164                         Peter Pan  1358983855
# 465558  138446     7164                visually appealing  1358983855
# 465559  138446    55999                           dragged  1358983772
# 465560  138446    55999                     Jason Bateman  1358983778
# 465561  138446    55999                            quirky  1358983778
# 465562  138446    55999                               sad  1358983772
# 465563  138472      923                     rise to power  1194037967
